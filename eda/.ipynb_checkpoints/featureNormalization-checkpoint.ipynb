# %%
from sklearn.feature_selection import RFE
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.dummy import DummyRegressor
from sklearn.metrics import mean_squared_error

from sklearn.preprocessing import StandardScaler

from statsmodels.formula.api import ols



from scipy import stats
import pandas as pd
import numpy as np
import seaborn as sns

import warnings 

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Goal of this Notebook
#
# I want to start testing which features need to be included or excluded from the analysis.
#
# Things I did:
# - dropped ID
# - converted to date to dt
# - dropped rennovation column. conducted a ttest between the houses with recent rennovations and without and found there was not significant evidence to reject the null hyptothesis.

# %%
df = pd.read_csv('../raw/kc_house_data_train.csv', index_col=0)

# %%
# Create new datasets for ease of future use
X = df.drop(columns="price")
X.to_csv("../raw/X.csv", index=False)

y = df['price']
y.to_csv("../raw/y.csv", index=False)

# %%
# List of columns to drop, iteratively add to this as I continue
to_drop = [
    'id',
    'yr_renovated'

]
X_train.drop(columns=to_drop, inplace=True)

# %%
# Split the data into training and test data
X_train, X_test, y_train, y_test = train_test_split(X, y,               # Pass in our X and y
                                                    random_state=42,    # Abritary select a random_state 
                                                    test_size=.2        # Split test size to be 20% of full data.
                                                   )

# %%
X_train.head()
# Out:
#                id             date  bedrooms  bathrooms  sqft_living  \
# 2498   1776460190  20140626T000000         3       2.50         2370
# 10932  2144800215  20140519T000000         4       1.75         2080
# 15638  7891600165  20140627T000000         1       1.00          700
# 15099  8732190200  20150115T000000         4       2.25         2490
# 15560  9122001230  20141205T000000         3       3.50         1970
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 2498       5353     2.0           0     0          3      8        2370
# 10932     13629     1.0           0     0          4      7        1040
# 15638      2500     1.0           0     0          4      7         700
# 15099      7233     1.0           0     0          3      8        1460
# 15560      5079     2.0           0     0          3      8        1680
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 2498               0      2009             0    98019  47.7333 -121.975
# 10932           1040      1955             0    98178  47.4866 -122.232
# 15638              0      1907             0    98106  47.5662 -122.364
# 15099           1030      1978             0    98023  47.3115 -122.396
# 15560            290      2007             0    98144  47.5816 -122.296
#
#        sqft_living15  sqft_lot15
# 2498            2130        6850
# 10932           1780       14659
# 15638           1340        5000
# 15099           2000        8000
# 15560           1940        6000

# %%
# List of columns to drop, iteratively add to this as I continue
to_drop = [
    'id',

]
X_train.drop(columns=to_drop, inplace=True)

# %%
X_train.head()
# Out:
#                   date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 2498   20140626T000000         3       2.50         2370      5353     2.0
# 10932  20140519T000000         4       1.75         2080     13629     1.0
# 15638  20140627T000000         1       1.00          700      2500     1.0
# 15099  20150115T000000         4       2.25         2490      7233     1.0
# 15560  20141205T000000         3       3.50         1970      5079     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 2498            0     0          3      8        2370              0
# 10932           0     0          4      7        1040           1040
# 15638           0     0          4      7         700              0
# 15099           0     0          3      8        1460           1030
# 15560           0     0          3      8        1680            290
#
#        yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 2498       2009             0    98019  47.7333 -121.975           2130
# 10932      1955             0    98178  47.4866 -122.232           1780
# 15638      1907             0    98106  47.5662 -122.364           1340
# 15099      1978             0    98023  47.3115 -122.396           2000
# 15560      2007             0    98144  47.5816 -122.296           1940
#
#        sqft_lot15
# 2498         6850
# 10932       14659
# 15638        5000
# 15099        8000
# 15560        6000

# %%
# Let's handle the date column first by converting it into date time
X_train.date = pd.to_datetime(X_train.date)

# %%
# look at the year renovated 
print(len(X_train.yr_renovated.value_counts()))
# 67 unique years. Let's rename the column to year since last renovation 

def years_passed(x, year=2014):
    return year-x

X_train['recent_reno'] = X_train.yr_renovated.apply(lambda x: years_passed(x)).value_counts()
# Given that the majority of houses have not been renovated, we should instead make 3 cats
#
# Out:
# 67

# %% [markdown]
# ### Hypothesis Alert!!!
# - renovations in the past 10 years will have effect on the price of the house
# - alternative, there will be a signeficant effect

# %%
def recent_rennovation (n):
    if n <= 10:
        return 1
    else:
        return 0

X_train.recent_reno = X_train.recent_reno.apply(recent_rennovation)

# %%
# perform a two way ttest
test = pd.concat([X_train, y_train], axis=1)
x = test[test.recent_reno == 1]
y = test[test.recent_reno == 0]
stats.ttest_ind(x.price, y.price, equal_var=False)
# Out:
# Ttest_indResult(statistic=0.6136789990311201, pvalue=0.5440271138210075)

# %% [markdown]
# ### Conclusion Alert!!
# - I have concluded tentatively that there is no effect of renovation on the outcome of the price.
# - A caveat is that the data sets are so vastly different that it is hard to draw a conclusion.

# %%
# Let's have a look at the year built and its effect on our model

# let's perform a simple linear regression 
formula = 'price~yr_built'
model = ols(formula=formula, data = pd.concat([X_train, y_train], axis=1)).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     43.12
# Date:                Sat, 17 Oct 2020   Prob (F-statistic):           5.33e-11
# Time:                        21:33:48   Log-Likelihood:            -1.9715e+05
# No. Observations:               13832   AIC:                         3.943e+05
# Df Residuals:                   13830   BIC:                         3.943e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -8.613e+05   2.14e+05     -4.028      0.000   -1.28e+06   -4.42e+05
# yr_built     712.3704    108.484      6.567      0.000     499.727     925.014
# ==============================================================================
# Omnibus:                    13073.950   Durbin-Watson:                   1.977
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1014162.003
# Skew:                           4.379   Prob(JB):                         0.00
# Kurtosis:                      44.024   Cond. No.                     1.32e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.32e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# That wasn't significant, but what if we do some feature normalization and modify the column
house_age = X_train.yr_built.apply(recent_rennovation)
X_train.age = house_age
scalar = StandardScaler()
# norm_age = scalar.fit_transform(house_age)

# %%
X_train.age
# Out:
# 2498     0
# 10932    0
# 15638    0
# 15099    0
# 15560    0
#         ..
# 11284    0
# 11964    0
# 5390     0
# 860      0
# 15795    0
# Name: age, Length: 13832, dtype: int64

# %%
formula = 'price~age'
model = ols(formula=formula, data = pd.concat([X_train, y_train], axis=1)).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     3.635
# Date:                Sat, 17 Oct 2020   Prob (F-statistic):             0.0566
# Time:                        21:32:28   Log-Likelihood:            -1.9717e+05
# No. Observations:               13832   AIC:                         3.943e+05
# Df Residuals:                   13830   BIC:                         3.944e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   5.426e+05   3191.633    170.018      0.000    5.36e+05    5.49e+05
# age        -6085.3398   3191.633     -1.907      0.057   -1.23e+04     170.693
# ==============================================================================
# Omnibus:                    13035.357   Durbin-Watson:                   1.978
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           998305.680
# Skew:                           4.362   Prob(JB):                         0.00
# Kurtosis:                      43.695   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
X_train.age.hist()

# %% [markdown]
# #### Interpretation Alert!!
#
# I think that the data indicates that though the variation in house age does little to explain the variation in house price, there is still a significant effect as the overall F score of the simple model is significant!

# %% [markdown]
# ## Next up, let's take a look at square footage

# %%
print(X_train.columns)
X_train.head()
# Out:
# Index(['date', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'recent_reno', 'age'],
#       dtype='object')
#             date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 2498  2014-06-26         3       2.50         2370      5353     2.0
# 10932 2014-05-19         4       1.75         2080     13629     1.0
# 15638 2014-06-27         1       1.00          700      2500     1.0
# 15099 2015-01-15         4       2.25         2490      7233     1.0
# 15560 2014-12-05         3       3.50         1970      5079     2.0
#
#        waterfront  view  condition  grade  ...  sqft_basement  yr_built  \
# 2498            0     0          3      8  ...              0      2009
# 10932           0     0          4      7  ...           1040      1955
# 15638           0     0          4      7  ...              0      1907
# 15099           0     0          3      8  ...           1030      1978
# 15560           0     0          3      8  ...            290      2007
#
#        yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  \
# 2498              0    98019  47.7333 -121.975           2130        6850
# 10932             0    98178  47.4866 -122.232           1780       14659
# 15638             0    98106  47.5662 -122.364           1340        5000
# 15099             0    98023  47.3115 -122.396           2000        8000
# 15560             0    98144  47.5816 -122.296           1940        6000
#
#        recent_reno  age
# 2498             0    0
# 10932            0    0
# 15638            0    0
# 15099            0    0
# 15560            0    0
#
# [5 rows x 21 columns]

# %%
size = ['sqft_living',
        'sqft_lot',
        "sqft_basement",
        "sqft_living15",
        "sqft_lot15"       
]
size_data = X_train[size]

# %%
sizes = pd.concat([size_data, y_train], axis=1)
columns = list(sizes.columns)

formula = 'price' + '~' + '+'.join(list(size_data.columns))
print(columns,formula)
sizes.head()
model = ols(formula=formula, data=sizes).fit()
# Out:
# ['sqft_living', 'sqft_lot', 'sqft_basement', 'sqft_living15', 'sqft_lot15', 'price'] price~sqft_living+sqft_lot+sqft_basement+sqft_living15+sqft_lot15

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.506
# Model:                            OLS   Adj. R-squared:                  0.506
# Method:                 Least Squares   F-statistic:                     2831.
# Date:                Sat, 17 Oct 2020   Prob (F-statistic):               0.00
# Time:                        22:00:39   Log-Likelihood:            -1.9229e+05
# No. Observations:               13832   AIC:                         3.846e+05
# Df Residuals:                   13826   BIC:                         3.846e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept     -1.084e+05   6873.289    -15.764      0.000   -1.22e+05   -9.49e+04
# sqft_living     238.4908      4.167     57.228      0.000     230.322     246.659
# sqft_lot          0.0808      0.074      1.087      0.277      -0.065       0.226
# sqft_basement    32.8389      5.751      5.710      0.000      21.567      44.111
# sqft_living15    76.0439      5.116     14.865      0.000      66.016      86.071
# sqft_lot15       -0.7317      0.114     -6.404      0.000      -0.956      -0.508
# ==============================================================================
# Omnibus:                    10643.696   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           590255.163
# Skew:                           3.214   Prob(JB):                         0.00
# Kurtosis:                      34.350   Cond. No.                     1.57e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.57e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ### Interpretation Alert!
#
# It seems that all but the square foot lot column is significant. I think that the Square foot lot column is actually the total square footage of the property, potentially not including the house.
#
# If it is the total square footage, then i should minus away the square footage of the house to find the size of the surrounding property!
#
# Otherwise, all the othervariables need to be taken into account
