# %%
import pandas as pd
import matplotlib.pyplot as plt
import descartes
import geopandas as gpd
from shapely.geometry import Point, Polygon

from warnings import filterwarnings

filterwarnings('ignore')

# %matplotlib inline

# %%
# !ls
# Out:
# ModelOne.ipynb                geohashingClustering.ipynb
# Months.ipynb                  holdoutZipcodes.ipynb
# Selecting key regions.ipynb   mapping.ipynb
# Traingeohashing.ipynb         month_dummy_model.ipynb
# featureNormalization.ipynb    outlierImputation.ipynb
# fixingBathBeds.ipynb          timeseriesInvestigation.ipynb

# %%
df = pd.read_csv("../raw/kc_house_data_train.csv", index_col=0)

# %%
# longitude is represented as a floating point number
df.head()
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  2591820310  20141006T000000   365000.0         4       2.25         2070
# 1  7974200820  20140821T000000   865000.0         5       3.00         2900
# 2  7701450110  20140815T000000  1038000.0         4       2.50         3770
# 3  9522300010  20150331T000000  1490000.0         3       3.50         4560
# 4  9510861140  20140714T000000   711000.0         3       2.50         2550
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      8893     2.0           0     0  ...      8        2070              0
# 1      6730     1.0           0     0  ...      8        1830           1070
# 2     10893     2.0           0     2  ...     11        3770              0
# 3     14608     2.0           0     2  ...     12        4560              0
# 4      5376     2.0           0     0  ...      9        2550              0
#
# ...

# %%
df.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.015644 -0.001529   0.003833    -0.014251 -0.129837
# price         -0.015644  1.000000  0.305106   0.524335     0.703540  0.086803
# bedrooms      -0.001529  0.305106  1.000000   0.507867     0.570428  0.029375
# bathrooms      0.003833  0.524335  0.507867   1.000000     0.755270  0.085470
# sqft_living   -0.014251  0.703540  0.570428   0.755270     1.000000  0.166810
# sqft_lot      -0.129837  0.086803  0.029375   0.085470     0.166810  1.000000
# floors         0.017126  0.256985  0.172975   0.497967     0.357169 -0.002205
# waterfront     0.000101  0.275779 -0.008581   0.065848     0.109738  0.015356
# view           0.012594  0.395485  0.079741   0.188817     0.283336  0.073058
# condition     -0.014272  0.036099  0.025266  -0.122976    -0.061530 -0.013715
# grade          0.003163  0.666215  0.354679   0.664191     0.762929  0.110320
# ...

# %%
# Let's get rid of the everything but the price, longitude and latitude for now
geometry = [Point(xy) for xy in zip(df["long"], df["lat"])]
geometry[:5]

# %%
crs = {'init': 'epsg:4326'}
geo_df = gpd.GeoDataFrame(df,
                         crs=crs,
                         geometry=geometry)

# %%
geo_df.head()
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  2591820310  20141006T000000   365000.0         4       2.25         2070
# 1  7974200820  20140821T000000   865000.0         5       3.00         2900
# 2  7701450110  20140815T000000  1038000.0         4       2.50         3770
# 3  9522300010  20150331T000000  1490000.0         3       3.50         4560
# 4  9510861140  20140714T000000   711000.0         3       2.50         2550
#
#    sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 0      8893     2.0           0     0  ...        2070              0
# 1      6730     1.0           0     0  ...        1830           1070
# 2     10893     2.0           0     2  ...        3770              0
# 3     14608     2.0           0     2  ...        4560              0
# 4      5376     2.0           0     0  ...        2550              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
map_df = gpd.read_file("../raw/mapping/kingscounty-shp/Cities_and_Unincorporated_King_County___city_kc_area.shp")

# %%
fig, ax = plt.subplots(figsize = (15,15))
map_df.plot(ax=ax,)

# %%
map_df.head()
# Out:
#    OBJECTID JURIS       CITYNAME     SHAPE_Leng    SHAPE_Area  \
# 0         1    AL         Algona   38144.667179  3.641105e+07
# 1         2    AU         Auburn  209231.046799  7.856892e+08
# 2         3    BA     Beaux Arts    6720.785802  2.274707e+06
# 3         4    BD  Black Diamond    6629.569588  2.412697e+06
# 4         5    BD  Black Diamond   85786.107116  1.983661e+08
#
#                                             geometry
# 0  POLYGON ((-122.24022 47.29353, -122.24307 47.2...
# 1  POLYGON ((-122.22820 47.35395, -122.22546 47.3...
# 2  POLYGON ((-122.20276 47.58679, -122.20276 47.5...
# 3  POLYGON ((-121.96191 47.28836, -121.96191 47.2...
# 4  POLYGON ((-122.04854 47.34368, -122.04412 47.3...

# %%
fig,ax = plt.subplots(figsize = (15,15))
# ax.set_ylim(5900000, 6300000)
# map_df.plot(ax=ax, alpha=0.4, color="blue")
geo_df.plot(ax=ax);

geo_df.to_csv('../cleanedData/geopandasTraining.csv', index=False)

# %%
map_df.head()
# Out:
#    OBJECTID JURIS       CITYNAME     SHAPE_Leng    SHAPE_Area  \
# 0         1    AL         Algona   38144.667179  3.641105e+07
# 1         2    AU         Auburn  209231.046799  7.856892e+08
# 2         3    BA     Beaux Arts    6720.785802  2.274707e+06
# 3         4    BD  Black Diamond    6629.569588  2.412697e+06
# 4         5    BD  Black Diamond   85786.107116  1.983661e+08
#
#                                             geometry
# 0  POLYGON ((-122.24022 47.29353, -122.24307 47.2...
# 1  POLYGON ((-122.22820 47.35395, -122.22546 47.3...
# 2  POLYGON ((-122.20276 47.58679, -122.20276 47.5...
# 3  POLYGON ((-121.96191 47.28836, -121.96191 47.2...
# 4  POLYGON ((-122.04854 47.34368, -122.04412 47.3...

# %%
geo_df.head()
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  2591820310  20141006T000000   365000.0         4       2.25         2070
# 1  7974200820  20140821T000000   865000.0         5       3.00         2900
# 2  7701450110  20140815T000000  1038000.0         4       2.50         3770
# 3  9522300010  20150331T000000  1490000.0         3       3.50         4560
# 4  9510861140  20140714T000000   711000.0         3       2.50         2550
#
#    sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 0      8893     2.0           0     0  ...        2070              0
# 1      6730     1.0           0     0  ...        1830           1070
# 2     10893     2.0           0     2  ...        3770              0
# 3     14608     2.0           0     2  ...        4560              0
# 4      5376     2.0           0     0  ...        2550              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
fig, ax = plt.subplots(figsize = (15,16))
map_df.plot(ax=ax, alpha = 0.8, color = 'Grey')
geo_df.plot(ax=ax,
            column ='price',
            cmap = 'inferno', 
            legend=True ,
            markersize = 2,
            marker = 'o',
            aspect = 1
           )
# geo_df.plot(ax = ax , markersize = 2, color = 'blue',marker =
#             'o',label = 'House', aspect = 1)
plt.legend(prop = {'size':10} )
ax.set_title('Houses in Kings County, WA', fontdict = {'fontsize':
                20})
ax.set_ylabel('Latitude',fontdict = {'fontsize': 20})
ax.set_xlabel('Longitude',fontdict = {'fontsize': 20})
# Out:
# No handles with labels found to put in legend.
# Text(0.5, 399.821450827886, 'Longitude')
